# %%
from qsurface.main import initialize, run, BenchmarkDecoder
code, decoder = initialize((3,3), "planar", "mwpm",plotting = True, enabled_errors=["pauli"])
run(code, decoder, iterations=1, error_rates = {"p_bitflip": 0.1, "p_phaseflip": 0.1})
# Out:
# Drawing 1/1: Initial
# Drawing 2/2: Errors applied
# Drawing 3/3: Ancilla-qubits measured
# Drawing 4/4: Matchings found
# Drawing 5/5: Decoded
# Drawing 6/6: Errors applied
# Drawing 7/7: Ancilla-qubits measured
# Drawing 8/8: Matchings found
# Drawing 9/9: Decoded
# {'no_error': 1}
